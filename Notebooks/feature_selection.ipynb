# %%
import pandas as pd
import logging

# Log fayl manzili
log_path = r"C:\Users\Rasulbek907\Desktop\Project_MP\Log\feature_selection.log"

# Log sozlamalari
logging.basicConfig(
    filename=log_path,
    filemode='a',  # Append mode
    format='%(asctime)s - %(levelname)s - %(message)s',
    level=logging.INFO
)

try:
    logging.info("CSV fayl o'qilmoqda:...")
    df = pd.read_csv(r"C:\Users\Rasulbek907\Desktop\Project_MP\Data\Preprosessed\Fully_Preprosessed_Data.csv")
    logging.info(f"Fayl muvaffaqiyatli o'qildi. Satırlar soni: {len(df)} ustunlar soni: {len(df.columns)}")
except Exception as e:
    logging.error(f"CSV faylni o'qishda xatolik: {e}")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4209 entries, 0 to 4208
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0.1         4209 non-null   int64
#  1   Unnamed: 0           4209 non-null   float64
#  2   id                   4209 non-null   float64
#  3   ref                  4209 non-null   float64
#  4   subtitle             4209 non-null   float64
#  5   creatorname          4209 non-null   float64
#  6   creatorurl           4209 non-null   float64
#  7   totalbytes           4209 non-null   float64
#  8   url                  4209 non-null   float64
#  9   lastupdated          4209 non-null   float64
#  10  downloadcount        4209 non-null   float64
#  11  ownername            4209 non-null   float64
#  12  ownerref             4209 non-null   float64
#  13  title                4209 non-null   float64
#  14  viewcount            4209 non-null   float64
#  15  tags                 4209 non-null   float64
#  16  cluster              4209 non-null   int64
#  17  anomaly              4209 non-null   float64
#  18  anomaly_label        4209 non-null   float64
#  19  download_view_ratio  4209 non-null   float64
#  20  engagement_score     4209 non-null   float64
#  21  num_tags             4209 non-null   float64
#  22  title_length         4209 non-null   float64
#  23  subtitle_length      4209 non-null   float64
#  24  creator_popularity   4209 non-null   float64
#  25  owner_popularity     4209 non-null   float64
#  26  lastupdated_year     4209 non-null   float64
#  27  lastupdated_month    4209 non-null   float64
#  28  lastupdated_day      4209 non-null   float64
#  29  lastupdated_weekday  4209 non-null   float64
# dtypes: float64(28), int64(2)
# memory usage: 986.6 KB

# %%
import pandas as pd
import plotly.express as px

# Raqamli ustunlarni tanlash
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

# faqat raqamli ustunlar bo'yicha korrelyatsiya
corr_matrix = df[numeric_cols].corr()

# cluster ustunining boshqa ustunlar bilan korrelyatsiyasi
cluster_corr = corr_matrix[['cluster']].sort_values(by='cluster', ascending=False)

# Heatmap uchun DataFrame ni transformatsiya qilish
heatmap_data = cluster_corr.reset_index()
heatmap_data.columns = ['Feature', 'Correlation_with_cluster']

# Plotly Express yordamida bar grafik
fig = px.bar(
    heatmap_data,
    x='Feature',
    y='Correlation_with_cluster',
    title='cluster bilan boshqa ustunlar o\'rtasidagi korrelyatsiya',
    labels={'Correlation_with_cluster': 'Korrelyatsiya qiymati', 'Feature': 'Xususiyatlar'}
)

fig.show()

# %%
import numpy as np
import plotly.figure_factory as ff

# Qiymatlarni 2 xonagacha qisqartirish
annot_text = np.around(corr_matrix.values, decimals=2).astype(str)

fig = ff.create_annotated_heatmap(
    z=corr_matrix.values,
    x=list(corr_matrix.columns),
    y=list(corr_matrix.index),
    annotation_text=annot_text,
    colorscale='Viridis',
    showscale=True
)

fig.update_layout(title='Raqamli ustunlar o\'rtasidagi korrelyatsiya matritsasi')
fig.show()

# %% [markdown]
# # Feature Selection Filtering

# %%
import seaborn as sns               
import matplotlib.pyplot as plt     


corr_matrix = df.corr().abs()  

upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))  


to_drop = [col for col in upper.columns if any(upper[col] > 0.8)]  
corr_matrix = df.corr().abs() 
print(corr_matrix)
# Out:
#                      Unnamed: 0.1  Unnamed: 0        id       ref  subtitle  \
# Unnamed: 0.1             1.000000    1.000000  0.074494  0.026376  0.014475
# Unnamed: 0               1.000000    1.000000  0.074494  0.026376  0.014475
# id                       0.074494    0.074494  1.000000  0.011051  0.052125
# ref                      0.026376    0.026376  0.011051  1.000000  0.013756
# subtitle                 0.014475    0.014475  0.052125  0.013756  1.000000
# creatorname              0.013552    0.013552  0.004221  0.652085  0.001785
# creatorurl               0.019395    0.019395  0.021447  0.968657  0.008544
# totalbytes               0.039561    0.039561  0.005497  0.031338  0.026658
# url                      0.026376    0.026376  0.011051  1.000000  0.013756
# lastupdated              0.052148    0.052148  0.928083  0.008294  0.043423
# downloadcount            0.342538    0.342538  0.292584  0.021292  0.009589
# ownername                0.018753    0.018753  0.004316  0.676748  0.005435
# ownerref                 0.024253    0.024253  0.008009  0.986583  0.008988
# title                    0.032323    0.032323  0.024657  0.019497  0.151654
# viewcount                0.331082    0.331082  0.332259  0.018406  0.012937
# tags                     0.013420    0.013420  0.008620  0.016135  0.022079
# cluster                  0.099597    0.099597  0.092439  0.035354  0.022488
# anomaly                  0.271517    0.271517  0.214328  0.014251  0.021169
# anomaly_label            0.271517    0.271517  0.214328  0.014251  0.021169
# download_view_ratio      0.000758    0.000758  0.041360  0.025777  0.012832
# engagement_score         0.336393    0.336393  0.325680  0.019225  0.012261
# num_tags                 0.077386    0.077386  0.141086  0.002278  0.035562
# title_length             0.006775    0.006775  0.229078  0.031375  0.035371
# subtitle_length          0.006915    0.006915  0.279724  0.011856  0.100031
# creator_popularity            NaN         NaN       NaN       NaN       NaN
# owner_popularity         0.057558    0.057558  0.061245  0.077158  0.026737
# lastupdated_year         0.001730    0.001730  0.874743  0.004676  0.041660
# lastupdated_month        0.089055    0.089055  0.233439  0.012362  0.019704
# lastupdated_day          0.012472    0.012472  0.006970  0.028290  0.015700
# lastupdated_weekday      0.003910    0.003910  0.002807  0.037054  0.001091
#
#                      creatorname  creatorurl  totalbytes       url  \
# Unnamed: 0.1            0.013552    0.019395    0.039561  0.026376
# Unnamed: 0              0.013552    0.019395    0.039561  0.026376
# id                      0.004221    0.021447    0.005497  0.011051
# ref                     0.652085    0.968657    0.031338  1.000000
# subtitle                0.001785    0.008544    0.026658  0.013756
# creatorname             1.000000    0.673897    0.038960  0.652085
# creatorurl              0.673897    1.000000    0.030253  0.968657
# totalbytes              0.038960    0.030253    1.000000  0.031338
# url                     0.652085    0.968657    0.031338  1.000000
# lastupdated             0.006809    0.021127    0.020638  0.008294
# downloadcount           0.002526    0.001259    0.035204  0.021292
# ownername               0.974147    0.656007    0.039369  0.676748
# ownerref                0.659366    0.980164    0.030625  0.986583
# title                   0.026457    0.013833    0.018595  0.019497
# viewcount               0.001374    0.000458    0.041502  0.018406
# tags                    0.023472    0.017265    0.010489  0.016135
# cluster                 0.028818    0.026035    0.656778  0.035354
# anomaly                 0.015920    0.009758    0.416697  0.014251
# anomaly_label           0.015920    0.009758    0.416697  0.014251
# download_view_ratio     0.022083    0.025660    0.010300  0.025777
# engagement_score        0.001653    0.000062    0.040368  0.019225
# num_tags                0.011417    0.008758    0.005366  0.002278
# title_length            0.000296    0.030276    0.034643  0.031375
# subtitle_length         0.025621    0.012890    0.018483  0.011856
# creator_popularity           NaN         NaN         NaN       NaN
# owner_popularity        0.010329    0.018943    0.010435  0.077158
# lastupdated_year        0.006793    0.021060    0.028559  0.004676
# lastupdated_month       0.004033    0.010587    0.013742  0.012362
# lastupdated_day         0.032052    0.028824    0.041509  0.028290
# lastupdated_weekday     0.026310    0.036882    0.025479  0.037054
#
#                      lastupdated  ...  engagement_score  num_tags  \
# Unnamed: 0.1            0.052148  ...          0.336393  0.077386
# Unnamed: 0              0.052148  ...          0.336393  0.077386
# id                      0.928083  ...          0.325680  0.141086
# ref                     0.008294  ...          0.019225  0.002278
# subtitle                0.043423  ...          0.012261  0.035562
# creatorname             0.006809  ...          0.001653  0.011417
# creatorurl              0.021127  ...          0.000062  0.008758
# totalbytes              0.020638  ...          0.040368  0.005366
# url                     0.008294  ...          0.019225  0.002278
# lastupdated             1.000000  ...          0.328405  0.166041
# downloadcount           0.298188  ...          0.973525  0.029610
# ownername               0.004010  ...          0.018224  0.007947
# ownerref                0.006940  ...          0.012485  0.000909
# title                   0.026692  ...          0.017564  0.042976
# viewcount               0.334092  ...          0.997643  0.025500
# tags                    0.022574  ...          0.024819  0.017128
# cluster                 0.088198  ...          0.326164  0.001006
# anomaly                 0.208717  ...          0.558135  0.007678
# anomaly_label           0.208717  ...          0.558135  0.007678
# download_view_ratio     0.045635  ...          0.007899  0.031050
# engagement_score        0.328405  ...          1.000000  0.026660
# num_tags                0.166041  ...          0.026660  1.000000
# title_length            0.220744  ...          0.093446  0.143678
# subtitle_length         0.266973  ...          0.083108  0.116644
# creator_popularity           NaN  ...               NaN       NaN
# owner_popularity        0.082638  ...          0.208164  0.044129
# lastupdated_year        0.963933  ...          0.365574  0.194790
# lastupdated_month       0.249046  ...          0.032415  0.022196
# lastupdated_day         0.026091  ...          0.015263  0.006423
# lastupdated_weekday     0.001588  ...          0.016296  0.007153
#
#                      title_length  subtitle_length  creator_popularity  \
# Unnamed: 0.1             0.006775         0.006915                 NaN
# Unnamed: 0               0.006775         0.006915                 NaN
# id                       0.229078         0.279724                 NaN
# ref                      0.031375         0.011856                 NaN
# subtitle                 0.035371         0.100031                 NaN
# creatorname              0.000296         0.025621                 NaN
# creatorurl               0.030276         0.012890                 NaN
# totalbytes               0.034643         0.018483                 NaN
# url                      0.031375         0.011856                 NaN
# lastupdated              0.220744         0.266973                 NaN
# downloadcount            0.095923         0.082524                 NaN
# ownername                0.004138         0.024980                 NaN
# ownerref                 0.030594         0.010061                 NaN
# title                    0.065281         0.039940                 NaN
# viewcount                0.091740         0.082427                 NaN
# tags                     0.035874         0.031452                 NaN
# cluster                  0.059295         0.000326                 NaN
# anomaly                  0.087634         0.035350                 NaN
# anomaly_label            0.087634         0.035350                 NaN
# download_view_ratio      0.013859         0.000829                 NaN
# engagement_score         0.093446         0.083108                 NaN
# num_tags                 0.143678         0.116644                 NaN
# title_length             1.000000         0.267966                 NaN
# subtitle_length          0.267966         1.000000                 NaN
# creator_popularity            NaN              NaN                 NaN
# owner_popularity         0.007099         0.006680                 NaN
# lastupdated_year         0.211079         0.250548                 NaN
# lastupdated_month        0.061426         0.059926                 NaN
# lastupdated_day          0.027985         0.023049                 NaN
# lastupdated_weekday      0.003483         0.006315                 NaN
#
#                      owner_popularity  lastupdated_year  lastupdated_month  \
# Unnamed: 0.1                 0.057558          0.001730           0.089055
# Unnamed: 0                   0.057558          0.001730           0.089055
# id                           0.061245          0.874743           0.233439
# ref                          0.077158          0.004676           0.012362
# subtitle                     0.026737          0.041660           0.019704
# creatorname                  0.010329          0.006793           0.004033
# creatorurl                   0.018943          0.021060           0.010587
# totalbytes                   0.010435          0.028559           0.013742
# url                          0.077158          0.004676           0.012362
# lastupdated                  0.082638          0.963933           0.249046
# downloadcount                0.216402          0.331308           0.025109
# ownername                    0.061684          0.007548           0.006692
# ownerref                     0.034913          0.002841           0.013446
# title                        0.008476          0.028298           0.008822
# viewcount                    0.203545          0.372094           0.034274
# tags                         0.013265          0.020762           0.016139
# cluster                      0.066274          0.094540           0.008038
# anomaly                      0.088172          0.229787           0.024128
# anomaly_label                0.088172          0.229787           0.024128
# download_view_ratio          0.004876          0.043388           0.008273
# engagement_score             0.208164          0.365574           0.032415
# num_tags                     0.044129          0.194790           0.022196
# title_length                 0.007099          0.211079           0.061426
# subtitle_length              0.006680          0.250548           0.059926
# creator_popularity                NaN               NaN                NaN
# owner_popularity             1.000000          0.120988           0.034094
# lastupdated_year             0.120988          1.000000           0.084316
# lastupdated_month            0.034094          0.084316           1.000000
# lastupdated_day              0.009097          0.023861           0.044986
# lastupdated_weekday          0.004386          0.003553           0.013827
#
#                      lastupdated_day  lastupdated_weekday
# Unnamed: 0.1                0.012472             0.003910
# Unnamed: 0                  0.012472             0.003910
# id                          0.006970             0.002807
# ref                         0.028290             0.037054
# subtitle                    0.015700             0.001091
# creatorname                 0.032052             0.026310
# creatorurl                  0.028824             0.036882
# totalbytes                  0.041509             0.025479
# url                         0.028290             0.037054
# lastupdated                 0.026091             0.001588
# downloadcount               0.017294             0.013951
# ownername                   0.029365             0.030290
# ownerref                    0.028676             0.034167
# title                       0.015971             0.010885
# viewcount                   0.014496             0.016832
# tags                        0.011681             0.002615
# cluster                     0.010943             0.020435
# anomaly                     0.005673             0.010798
# anomaly_label               0.005673             0.010798
# download_view_ratio         0.008774             0.022394
# engagement_score            0.015263             0.016296
# num_tags                    0.006423             0.007153
# title_length                0.027985             0.003483
# subtitle_length             0.023049             0.006315
# creator_popularity               NaN                  NaN
# owner_popularity            0.009097             0.004386
# lastupdated_year            0.023861             0.003553
# lastupdated_month           0.044986             0.013827
# lastupdated_day             1.000000             0.001382
# lastupdated_weekday         0.001382             1.000000
#
# [30 rows x 30 columns]

# %%
# Unnamed ustunlarni drop qilish
df = df.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'])

# Natijani tekshirish
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4209 entries, 0 to 4208
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   4209 non-null   float64
#  1   ref                  4209 non-null   float64
#  2   subtitle             4209 non-null   float64
#  3   creatorname          4209 non-null   float64
#  4   creatorurl           4209 non-null   float64
#  5   totalbytes           4209 non-null   float64
#  6   url                  4209 non-null   float64
#  7   lastupdated          4209 non-null   float64
#  8   downloadcount        4209 non-null   float64
#  9   ownername            4209 non-null   float64
#  10  ownerref             4209 non-null   float64
#  11  title                4209 non-null   float64
#  12  viewcount            4209 non-null   float64
#  13  tags                 4209 non-null   float64
#  14  cluster              4209 non-null   int64
#  15  anomaly              4209 non-null   float64
#  16  anomaly_label        4209 non-null   float64
#  17  download_view_ratio  4209 non-null   float64
#  18  engagement_score     4209 non-null   float64
#  19  num_tags             4209 non-null   float64
#  20  title_length         4209 non-null   float64
#  21  subtitle_length      4209 non-null   float64
#  22  creator_popularity   4209 non-null   float64
#  23  owner_popularity     4209 non-null   float64
#  24  lastupdated_year     4209 non-null   float64
#  25  lastupdated_month    4209 non-null   float64
#  26  lastupdated_day      4209 non-null   float64
#  27  lastupdated_weekday  4209 non-null   float64
# dtypes: float64(27), int64(1)
# memory usage: 920.8 KB
# None

# %%
import numpy as np   

corr_matrix = df.corr().abs()  

upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))  

to_drop = [col for col in upper.columns if any(upper[col] > 0.95)]  

df_filtered = df.drop(columns=to_drop)  
print("\nOriginal shape:", df.shape)  

print("Shape after dropping correlated features:", df_filtered.shape)
# Out:
# Original shape: (4209, 28)
# Shape after dropping correlated features: (4209, 20)

# %%
import numpy as np   

corr_matrix = df.corr().abs()  
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))  
to_drop = [col for col in upper.columns if any(upper[col] > 0.95)]  

print("Tushirib qoldirilgan (yuqori korrelyatsiyali) ustunlar:")
print(to_drop)
# Out:
# Tushirib qoldirilgan (yuqori korrelyatsiyali) ustunlar:
# ['creatorurl', 'url', 'ownername', 'ownerref', 'viewcount', 'anomaly_label', 'engagement_score', 'lastupdated_year']

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4209 entries, 0 to 4208
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   4209 non-null   float64
#  1   ref                  4209 non-null   float64
#  2   subtitle             4209 non-null   float64
#  3   creatorname          4209 non-null   float64
#  4   totalbytes           4209 non-null   float64
#  5   lastupdated          4209 non-null   float64
#  6   downloadcount        4209 non-null   float64
#  7   title                4209 non-null   float64
#  8   tags                 4209 non-null   float64
#  9   cluster              4209 non-null   int64
#  10  anomaly              4209 non-null   float64
#  11  download_view_ratio  4209 non-null   float64
#  12  num_tags             4209 non-null   float64
#  13  title_length         4209 non-null   float64
#  14  subtitle_length      4209 non-null   float64
#  15  creator_popularity   4209 non-null   float64
#  16  owner_popularity     4209 non-null   float64
#  17  lastupdated_month    4209 non-null   float64
#  18  lastupdated_day      4209 non-null   float64
#  19  lastupdated_weekday  4209 non-null   float64
# dtypes: float64(19), int64(1)
# memory usage: 657.8 KB

# %%
# Yuqori korrelyatsiyaga ega juftliklarni saqlash uchun bo‘sh ro‘yxat yaratamiz
high_corr_pairs = []


for col in upper.columns:
    
    for row in upper.index:
        
        if upper.loc[row, col] is not np.nan and upper.loc[row, col] > 0.95:
            
            high_corr_pairs.append([row, col, round(upper.loc[row, col], 2)])


corr_table = pd.DataFrame(high_corr_pairs, columns=['Feature 1', 'Feature 2', 'Correlation'])

print("Highly correlated feature pairs (correlation > 0.95):")
print(corr_table)
# Out:
# Highly correlated feature pairs (correlation > 0.95):
#         Feature 1         Feature 2  Correlation
# 0             ref        creatorurl         0.97
# 1             ref               url         1.00
# 2      creatorurl               url         0.97
# 3     creatorname         ownername         0.97
# 4             ref          ownerref         0.99
# 5      creatorurl          ownerref         0.98
# 6             url          ownerref         0.99
# 7   downloadcount         viewcount         0.96
# 8         anomaly     anomaly_label         1.00
# 9   downloadcount  engagement_score         0.97
# 10      viewcount  engagement_score         1.00
# 11    lastupdated  lastupdated_year         0.96

# %%
import plotly.express as px  

corr_long = corr_matrix.reset_index().melt(id_vars='index')  

corr_long.columns = ['Feature 1', 'Feature 2', 'Correlation']  

fig = px.imshow(
    corr_matrix,                  
    text_auto='.2f',              
    aspect="auto",                
    color_continuous_scale='RdBu_r',  
    zmin=-1, zmax=1,             
    title="Correlation Matrix Heatmap (Interactive)"  
)


fig.update_layout(
    width=900,          
    height=800,          
    xaxis_title="Features",  
    yaxis_title="Features"   
)

fig.show()

# %% [markdown]
# # Low Variance

# %%
# Low Variance
from sklearn.feature_selection import VarianceThreshold  
threshold = 0.01  
selector = VarianceThreshold(threshold=threshold)  
selector.fit(df_filtered)  
low_variance_features = df_filtered.columns[~selector.get_support()] 
df_low_variance_filtered = df_filtered.drop(columns=low_variance_features)  
print("\nOriginal shape:", df_filtered.shape)  
print("Shape after dropping low-variance features:", df_low_variance_filtered.shape)
# Out:
# Original shape: (4209, 20)
# Shape after dropping low-variance features: (4209, 19)

# %%
# Past variansli ustunlarni aniqlash:

low_variance_features = df_filtered.columns[~selector.get_support()]
print("Features with low variance (to drop):", list(low_variance_features))
# Out:
# Features with low variance (to drop): ['creator_popularity']

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns
variances = df[numeric_cols].var()
threshold = 0.01
low_variance_features = variances[variances < threshold].index.tolist()
var_df = pd.DataFrame({
    'Feature': variances.index,
    'Variance': variances.values,
    'LowVariance': ['Yes' if f in low_variance_features else 'No' for f in variances.index]
})


fig = px.bar(
    var_df,
    x='Feature',        
    y='Variance',       
    color='LowVariance',  
    color_discrete_map={'Yes': 'red', 'No': 'blue'},  
    text='Variance',    
    title='Feature Variance (Low-Variance Highlighted in Red)'  
)


fig.update_layout(
    xaxis_tickangle=-45,
    width=1000,
    height=600
)

fig.show()

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4209 entries, 0 to 4208
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   4209 non-null   float64
#  1   ref                  4209 non-null   float64
#  2   subtitle             4209 non-null   float64
#  3   creatorname          4209 non-null   float64
#  4   totalbytes           4209 non-null   float64
#  5   lastupdated          4209 non-null   float64
#  6   downloadcount        4209 non-null   float64
#  7   title                4209 non-null   float64
#  8   tags                 4209 non-null   float64
#  9   cluster              4209 non-null   int64
#  10  anomaly              4209 non-null   float64
#  11  download_view_ratio  4209 non-null   float64
#  12  num_tags             4209 non-null   float64
#  13  title_length         4209 non-null   float64
#  14  subtitle_length      4209 non-null   float64
#  15  creator_popularity   4209 non-null   float64
#  16  owner_popularity     4209 non-null   float64
#  17  lastupdated_month    4209 non-null   float64
#  18  lastupdated_day      4209 non-null   float64
#  19  lastupdated_weekday  4209 non-null   float64
# dtypes: float64(19), int64(1)
# memory usage: 657.8 KB

# %%
df_filtered.to_csv(r"C:\Users\Rasulbek907\Desktop\Project_MP\Data\Feature_Selection\Filtered_Features.csv")

# %% [markdown]
# # Feature Selection Wrapper

# %% [markdown]
#  # RFE + Linear Regression

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

X = df.drop('cluster', axis=1)
y = df['cluster']

# %%
# Oddiy chiziqli regressiya modelini yaratamiz (bu model RFE uchun asos bo'ladi)
model = LinearRegression()
rfe = RFE(model, n_features_to_select=20)
rfe.fit(X, y)
selected_features = X.columns[rfe.support_]
print("Selected features:", selected_features)
# Out:
# Selected features: Index(['id', 'ref', 'creatorname', 'creatorurl', 'totalbytes', 'url',
#        'lastupdated', 'downloadcount', 'ownername', 'ownerref', 'title',
#        'viewcount', 'tags', 'anomaly', 'anomaly_label', 'engagement_score',
#        'owner_popularity', 'lastupdated_year', 'lastupdated_month',
#        'lastupdated_day'],
#       dtype='object')

# %% [markdown]
# # RFE + RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE

model = RandomForestRegressor()
rfe = RFE(model, n_features_to_select=20)
rfe.fit(X, y)

selected_features = X.columns[rfe.support_]
print("Selected features (RandomForest):", selected_features)
# Out:
# Selected features (RandomForest): Index(['id', 'ref', 'subtitle', 'creatorname', 'totalbytes', 'url',
#        'lastupdated', 'downloadcount', 'ownername', 'ownerref', 'viewcount',
#        'tags', 'download_view_ratio', 'engagement_score', 'num_tags',
#        'title_length', 'subtitle_length', 'lastupdated_month',
#        'lastupdated_day', 'lastupdated_weekday'],
#       dtype='object')

# %% [markdown]
# # RFE + Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
rfe = RFE(model, n_features_to_select=20)
rfe.fit(X, y)

selected_features = X.columns[rfe.support_]
print("Selected features (DecisionTree):", selected_features)
# Out:
# Selected features (DecisionTree): Index(['totalbytes', 'downloadcount', 'ownername', 'ownerref', 'title',
#        'viewcount', 'tags', 'anomaly', 'anomaly_label', 'download_view_ratio',
#        'engagement_score', 'num_tags', 'title_length', 'subtitle_length',
#        'creator_popularity', 'owner_popularity', 'lastupdated_year',
#        'lastupdated_month', 'lastupdated_day', 'lastupdated_weekday'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# Model va ustun sonlarini saqlash uchun bo'sh ro'yxat
models = {
    "Linear Regression": LinearRegression(),
    "Random Forest": RandomForestRegressor(),
    "Decision Tree": DecisionTreeRegressor()    
}

results = []

# X va y aniq ekanligini faraz qilamiz
for name, model in models.items():
    rfe = RFE(model, n_features_to_select=20)  # 20 ta ustun tanlaymiz misol uchun
    rfe.fit(X, y)
    selected_count = sum(rfe.support_)
    results.append({'Model': name, 'Selected Features Count': selected_count})

# Natijalarni DataFrame ko'rinishida chiqaramiz
results_df = pd.DataFrame(results)
print(results_df)
# Out:
#                Model  Selected Features Count
# 0  Linear Regression                       20
# 1      Random Forest                       20
# 2      Decision Tree                       20

# %%
import pandas as pd
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
import os

X = df.drop('cluster', axis=1)
y = df['cluster']

model = LinearRegression()
rfe = RFE(model, n_features_to_select=20)
rfe.fit(X, y)

selected_features = X.columns[rfe.support_]

# Tanlangan ustunlarni DataFrame ga aylantirish
selected_df = pd.DataFrame(selected_features, columns=['Selected Features'])

# Saqlash uchun yo'l
save_path = r"C:\Users\Rasulbek907\Desktop\Project_MP\Data\Feature_Selection"
os.makedirs(save_path, exist_ok=True)  # Agar papka mavjud bo'lmasa, yaratadi

# To'liq fayl nomi
file_path = os.path.join(save_path, "Wrapper.csv")

# CSV ga saqlash
selected_df.to_csv(file_path, index=False)

print(f"Tanlangan ustunlar {file_path} ga saqlandi.")
# Out:
# Tanlangan ustunlar C:\Users\Rasulbek907\Desktop\Project_MP\Data\Feature_Selection\Wrapper.csv ga saqlandi.

# %% [markdown]
# # Feature Selection Embedded + Lasso CV

# %%
# Xususiyat tanlash uchun Linear Model'larda ishlatiladigan usul (LASSO regression)

# LassoCV (L1-regularizatsiya) ni import qilamiz
# CV - cross-validation, u model uchun optimal alpha (regulyarizatsiya kuchi) tanlab beradi
from sklearn.linear_model import LassoCV
X = df.drop('cluster', axis=1)
y = df['cluster']
lasso = LassoCV(cv=10, random_state=42).fit(X, y)
importance = np.abs(lasso.coef_)
selected_features = X.columns[importance > 0]
print("Selected features using Lasso (non-zero coefficients):")
print(selected_features.tolist())
# Out:
# Selected features using Lasso (non-zero coefficients):
# ['totalbytes', 'downloadcount', 'anomaly', 'anomaly_label', 'engagement_score']

# %%
# Faqat muhim featurelarni saqlab qolish
percentile_threshold = np.percentile(importance, 90) 
top_features = X.columns[importance >= percentile_threshold]
print("\nTop 25% important features based on Lasso coefficients:")
print(top_features.tolist())
# Out:
# Top 25% important features based on Lasso coefficients:
# ['totalbytes', 'anomaly', 'engagement_score']

# %%
# Feature importance'ni jadval shaklida tayyorlash

feat_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': importance
})

# Importance qiymatlariga qarab kamayish tartibida (eng muhimdan kam muhimga qarab) saralaymiz
feat_df = feat_df.sort_values(by='Importance', ascending=False)
percentile_threshold = np.percentile(importance, 85)
feat_df['Top15%'] = np.where(feat_df['Importance'] >= percentile_threshold, 'Yes', 'No')
print("Feature Importance Table:")
print(feat_df)
# Out:
# Feature Importance Table:
#                 Feature    Importance Top15%
# 14              anomaly  3.185846e-01    Yes
# 5            totalbytes  2.735008e-01    Yes
# 17     engagement_score  1.041930e-02    Yes
# 8         downloadcount  9.840738e-03    Yes
# 15        anomaly_label  1.276242e-15     No
# 2              subtitle  0.000000e+00     No
# 3           creatorname  0.000000e+00     No
# 6                   url  0.000000e+00     No
# 1                   ref  0.000000e+00     No
# 4            creatorurl  0.000000e+00     No
# 0                    id  0.000000e+00     No
# 10             ownerref  0.000000e+00     No
# 9             ownername  0.000000e+00     No
# 7           lastupdated  0.000000e+00     No
# 11                title  0.000000e+00     No
# 13                 tags  0.000000e+00     No
# 12            viewcount  0.000000e+00     No
# 16  download_view_ratio  0.000000e+00     No
# 18             num_tags  0.000000e+00     No
# 19         title_length  0.000000e+00     No
# 20      subtitle_length  0.000000e+00     No
# 21   creator_popularity  0.000000e+00     No
# 22     owner_popularity  0.000000e+00     No
# 23     lastupdated_year  0.000000e+00     No
# 24    lastupdated_month  0.000000e+00     No
# 25      lastupdated_day  0.000000e+00     No
# 26  lastupdated_weekday  0.000000e+00     No

# %%
fig = px.bar(
    feat_df,                
    x='Feature',            
    y='Importance',         
    color='Top15%',         
    color_discrete_map={'Yes': 'red', 'No': 'blue'},  
    text='Importance',      
    title='Lasso Feature Importance'  
)


fig.update_layout(
    xaxis_tickangle=-45,  
    width=1000,           
    height=600            
)

fig.show()

# %% [markdown]
# # Feature Selection Embedded + Random Forest Regression

# %%
# --- Tree based (Random Forest) Feature Importance ---

# Random Forest Regressorni import qilamiz
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=500, random_state=42)

rf.fit(X, y)

importances = rf.feature_importances_
feat_df = pd.DataFrame({
    'Feature': X.columns,       
    'Importance': importances   
})
feat_df = feat_df.sort_values(by='Importance', ascending=False)
percentile_threshold = np.percentile(importances, 85)
feat_df['Top15%'] = np.where(feat_df['Importance'] >= percentile_threshold, 'Yes', 'No')
print("Random Forest Feature Importance Table:")
print(feat_df)
# Out:
# Random Forest Feature Importance Table:
#                 Feature  Importance Top15%
# 5            totalbytes    0.822224    Yes
# 17     engagement_score    0.163317    Yes
# 8         downloadcount    0.012662    Yes
# 12            viewcount    0.000752    Yes
# 16  download_view_ratio    0.000144     No
# 25      lastupdated_day    0.000110     No
# 0                    id    0.000089     No
# 7           lastupdated    0.000076     No
# 24    lastupdated_month    0.000074     No
# 1                   ref    0.000066     No
# 18             num_tags    0.000064     No
# 2              subtitle    0.000057     No
# 6                   url    0.000052     No
# 13                 tags    0.000049     No
# 20      subtitle_length    0.000046     No
# 26  lastupdated_weekday    0.000039     No
# 4            creatorurl    0.000035     No
# 10             ownerref    0.000031     No
# 19         title_length    0.000031     No
# 23     lastupdated_year    0.000018     No
# 11                title    0.000016     No
# 3           creatorname    0.000013     No
# 14              anomaly    0.000013     No
# 9             ownername    0.000012     No
# 15        anomaly_label    0.000012     No
# 22     owner_popularity    0.000002     No
# 21   creator_popularity    0.000000     No

# %%
# Plotly Express yordamida Random Forest feature importance'ni grafik ko'rinishida chiqaramiz
fig = px.bar(
    feat_df,                
    x='Feature',            
    y='Importance',         
    color='Top15%',         
    color_discrete_map={'Yes': 'red', 'No': 'blue'},  
    text='Importance',      
    title='Random Forest Feature Importance'  
)


fig.update_layout(
    xaxis_tickangle=-45,  
    width=1000,           
    height=600            
)

fig.show()

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LassoCV
import os

# ====== 1. Ma'lumotlarni ajratish ======
X = df.drop('cluster', axis=1)
y = df['cluster']

# ====== 2. LassoCV modeli ======
lasso = LassoCV(cv=10, random_state=42).fit(X, y)

# ====== 3. Importance qiymatlari ======
importance = np.abs(lasso.coef_)

# Nolga teng bo'lmagan koeffitsientlar bo'yicha tanlangan ustunlar
selected_features = X.columns[importance > 0]

print("Selected features using Lasso (non-zero coefficients):")
print(selected_features.tolist())

# ====== 4. Top 10% muhim ustunlar ======
percentile_threshold = np.percentile(importance, 90)
top_features = X.columns[importance >= percentile_threshold]

print("\nTop 10% important features based on Lasso coefficients:")
print(top_features.tolist())

# ====== 5. Feature importance jadvali yaratish ======
feat_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': importance
})

# Muqaddaslik bo'yicha kamayish tartibida saralash
feat_df = feat_df.sort_values(by='Importance', ascending=False)

# 90 foizlik percentile chegarasini belgilash
percentile_threshold_90 = np.percentile(importance, 90)
feat_df['Top10%'] = np.where(feat_df['Importance'] >= percentile_threshold_90, 'Yes', 'No')

print("\nFeature Importance Table:")
print(feat_df)

# ====== 6. Fayl saqlash yo'lini aniqlash ======
save_path = r"C:\Users\Rasulbek907\Desktop\Project_MP\Data\Feature_Selection"
os.makedirs(save_path, exist_ok=True)

# Fayl nomlarini yaratish
embedded_file = os.path.join(save_path, "embedded.csv")
importance_file = os.path.join(save_path, "importance_table.csv")

# ====== 7. Natijalarni CSV ga saqlash ======
# Tanlangan (nolga teng bo'lmagan) ustunlar
pd.DataFrame(selected_features, columns=['Selected_Features']).to_csv(embedded_file, index=False)

# Importance jadvalini saqlash
feat_df.to_csv(importance_file, index=False)

print(f"\n✅ Tanlangan ustunlar '{embedded_file}' fayliga saqlandi.")
print(f"✅ Feature importance jadvali '{importance_file}' fayliga saqlandi.")
# Out:
# Selected features using Lasso (non-zero coefficients):
# ['totalbytes', 'downloadcount', 'anomaly', 'anomaly_label', 'engagement_score']
#
# Top 10% important features based on Lasso coefficients:
# ['totalbytes', 'anomaly', 'engagement_score']
#
# Feature Importance Table:
#                 Feature    Importance Top10%
# 14              anomaly  3.185846e-01    Yes
# 5            totalbytes  2.735008e-01    Yes
# 17     engagement_score  1.041930e-02    Yes
# 8         downloadcount  9.840738e-03     No
# 15        anomaly_label  1.276242e-15     No
# 2              subtitle  0.000000e+00     No
# 3           creatorname  0.000000e+00     No
# 6                   url  0.000000e+00     No
# 1                   ref  0.000000e+00     No
# 4            creatorurl  0.000000e+00     No
# 0                    id  0.000000e+00     No
# 10             ownerref  0.000000e+00     No
# 9             ownername  0.000000e+00     No
# 7           lastupdated  0.000000e+00     No
# 11                title  0.000000e+00     No
# 13                 tags  0.000000e+00     No
# 12            viewcount  0.000000e+00     No
# 16  download_view_ratio  0.000000e+00     No
# 18             num_tags  0.000000e+00     No
# 19         title_length  0.000000e+00     No
# 20      subtitle_length  0.000000e+00     No
# 21   creator_popularity  0.000000e+00     No
# 22     owner_popularity  0.000000e+00     No
# 23     lastupdated_year  0.000000e+00     No
# 24    lastupdated_month  0.000000e+00     No
# 25      lastupdated_day  0.000000e+00     No
# 26  lastupdated_weekday  0.000000e+00     No
#
# ✅ Tanlangan ustunlar 'C:\Users\Rasulbek907\Desktop\Project_MP\Data\Feature_Selection\embedded.csv' fayliga saqlandi.
# ✅ Feature importance jadvali 'C:\Users\Rasulbek907\Desktop\Project_MP\Data\Feature_Selection\importance_table.csv' fayliga saqlandi.
