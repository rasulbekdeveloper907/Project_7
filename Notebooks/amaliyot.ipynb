# %% [markdown]
# # Funksiyalarni chuqur o`rganish

# %% [markdown]
# # Funksiya bu - biror vazifani bararuvchi kodlar bloki

# %%
def funksiya_nomi(parametrlar):
    return qiymat

# %%
def salom_ber():
    print("Salom Akajon")

# %% [markdown]
# # parametrli funksiya

# %%
def salom_ber(ism):
    print(f"Salom , {ism}")


salom_ber("Durdona")
salom_ber("Malikaxon")

# %% [markdown]
# # bir nechta argumentlar bilan

# %%
def yigindi(a, b):
    natija = a + b 
    print(f"{a} + {b} = {natija}")


yigindi(41, 8)
