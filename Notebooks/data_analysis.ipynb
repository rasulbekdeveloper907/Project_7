# %%
import pandas as pd
import logging

# Log fayl manzili
log_path = r"C:\Users\Rasulbek907\Desktop\Project_MP\Log\data_loader.log"

# Log sozlamalari
logging.basicConfig(
    filename=log_path,
    filemode='a',  # Append mode
    format='%(asctime)s - %(levelname)s - %(message)s',
    level=logging.INFO
)

try:
    logging.info("CSV fayl o'qilmoqda:...")
    df = pd.read_csv(r"C:\Users\Rasulbek907\Desktop\Project_MP\Data\Raw_Data\Raw_Data.csv")
    logging.info(f"Fayl muvaffaqiyatli o'qildi. Satırlar soni: {len(df)} ustunlar soni: {len(df.columns)}")
except Exception as e:
    logging.error(f"CSV faylni o'qishda xatolik: {e}")

# %% [markdown]
# # DF Ustunlari haqida Malumot

# %% [markdown]
# | Ustun nomi                  | Izoh                                                                 |
# |------------------------------|----------------------------------------------------------------------|
# | Unnamed: 0                   | DataFrame indeksi yoki avtomatik yaratilgan ustun                   |
# | id                           | Datasetning noyob identifikatori (Kaggle ID)                        |
# | ref                          | Datasetga URL yoki ichki referens link                               |
# | subtitle                      | Datasetning qisqa tavsifi                                           |
# | creator_name                  | Datasetni yaratgan foydalanuvchi yoki muallif nomi                  |
# | creator_url                   | Muallifning Kaggle profiliga link                                   |
# | total_bytes                   | Dataset hajmi baytlarda                                             |
# | url                           | Dataset sahifasiga to‘g‘ridan-to‘g‘ri link                          |
# | last_updated                  | Dataset oxirgi yangilangan sanasi                                   |
# | download_count                | Dataset necha marta yuklab olinganligi                              |
# | is_private                    | Dataset shaxsiy yoki ommaviy ekanligi (True/False)                  |
# | is_featured                   | Kaggle tomonidan tavsiya qilingan dataset (True/False)              |
# | license_name                  | Dataset litsenziyasi nomi                                           |
# | owner_name                    | Dataset egasi yoki yuklagan foydalanuvchi nomi                      |
# | owner_ref                     | Egasi identifikatori                                                 |
# | kernel_count                  | Ushbu datasetga bog‘langan Kernel (Notebook) soni                   |
# | title                         | Dataset nomi                                                         |
# | topic_count                   | Dataset bilan bog‘liq mavzular soni                                  |
# | view_count                    | Dataset sahifasini ko‘rishlar soni                                   |
# | vote_count                    | Datasetga berilgan ovozlar soni                                      |
# | current_version_number         | Hozirgi versiya raqami                                               |
# | usability_rating              | Dataset foydalilik reytingi                                          |
# | tags                          | Datasetga berilgan teglar yoki kategoriyalar                         |
# | files                         | Datasetdagi fayllar ro‘yxati                                         |
# | versions                      | Dataset versiyalari ro‘yxati                                         |
# | is_frozen                     | Dataset o‘zgartirilmaydigan yoki muzlatilganligini bildiradi         |
