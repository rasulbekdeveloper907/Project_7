# %%
import pandas as pd
import logging

# Log fayl manzili
log_path = r"C:\Users\Rasulbek907\Desktop\Project_MP\Log\data_loader.log"

# Log sozlamalari
logging.basicConfig(
    filename=log_path,
    filemode='a',  # Append mode
    format='%(asctime)s - %(levelname)s - %(message)s',
    level=logging.INFO
)

try:
    logging.info("CSV fayl o'qilmoqda:...")
    df = pd.read_csv(r"C:\Users\Rasulbek907\Desktop\Project_MP\Data\Web_Scrapping\kaggle_datasets_5000.csv")
    logging.info(f"Fayl muvaffaqiyatli o'qildi. Satırlar soni: {len(df)} ustunlar soni: {len(df.columns)}")
except Exception as e:
    logging.error(f"CSV faylni o'qishda xatolik: {e}")

# %%
df.head()
# Out:
#        _id                                               _ref  \
# 0  8630082            anandshaw2001/amazon-product-sales-2025
# 1  8385511  ahmeduzaki/global-earthquake-tsunami-risk-asse...
# 2  8582733                     ranaghulamnabi/bmw-car-dataset
# 3  8310166  ahmadrazakashif/bmw-worldwide-sales-records-20...
# 4  8395374                    jaderz/hospital-beds-management
#
#                                            _subtitle       _creator_name  \
# 0  Amazon Diwali Product Sales 2025 and Sentiment...          Anand Shaw
# 1  Seismic Features & Tsunami Classification Data...  Ahmed Mohamed Zaki
# 2  Predicting BMW car prices using data-driven in...   Coding expert G.N
# 3  A complete dataset of BMW cars from 2010–2024 ...   Ahmad Raza Kashif
# 4  Hospital simulation datasets studying workload...          Weiwei Zhu
#
#       _creator_url  _total_bytes  \
# 0    anandshaw2001        397394
# 1       ahmeduzaki         16151
# 2   ranaghulamnabi        112601
# 3  ahmadrazakashif        853348
# 4           jaderz         47583
#
#                                                 _url            _last_updated  \
# 0  https://www.kaggle.com/datasets/anandshaw2001/...  2025-11-02 06:45:32.877
# 1  https://www.kaggle.com/datasets/ahmeduzaki/glo...  2025-10-01 16:35:53.273
# 2  https://www.kaggle.com/datasets/ranaghulamnabi...  2025-10-27 09:51:38.037
# 3  https://www.kaggle.com/datasets/ahmadrazakashi...  2025-09-20 14:39:45.280
# 4  https://www.kaggle.com/datasets/jaderz/hospita...  2025-10-03 09:21:58.590
#
#    _download_count  _is_private  ...  \
# 0             1106        False  ...
# 1            18702        False  ...
# 2              885        False  ...
# 3            21623        False  ...
# 4            15809        False  ...
#
#                                               _title _topic_count  \
# 0                   Amazon Diwali Product Sales 2025            0
# 1  Global Earthquake-Tsunami Risk Assessment Dataset            0
# 2       BMW Cars Dataset Based on Features and Price            0
# 3            BMW Worldwide Sales Records (2010–2024)            0
# 4                           Hospital Beds Management            0
#
#    _view_count _vote_count _current_version_number  _usability_rating  \
# 0         3928          26                       1                1.0
# 1        86436         632                       1                1.0
# 2         2950          22                       1                1.0
# 3        72221         416                       1                1.0
# 4        61054         366                       1                1.0
#
#                                                _tags  _files  _versions  \
# 0  [{"ref": "clothing and accessories", "name": "...      []         []
# 1  [{"ref": "exploratory data analysis", "name": ...      []         []
# 2  [{"ref": "automobiles and vehicles", "name": "...      []         []
# 3  [{"ref": "business", "name": "business", "desc...      []         []
# 4  [{"ref": "healthcare", "name": "healthcare", "...      []         []
#
#    _is_frozen
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   _id                      5000 non-null   int64
#  1   _ref                     5000 non-null   object
#  2   _subtitle                5000 non-null   object
#  3   _creator_name            5000 non-null   object
#  4   _creator_url             5000 non-null   object
#  5   _total_bytes             5000 non-null   int64
#  6   _url                     5000 non-null   object
#  7   _last_updated            5000 non-null   object
#  8   _download_count          5000 non-null   int64
#  9   _is_private              5000 non-null   bool
#  10  _is_featured             5000 non-null   bool
#  11  _license_name            5000 non-null   object
#  12  _description             0 non-null      float64
#  13  _owner_name              5000 non-null   object
#  14  _owner_ref               5000 non-null   object
#  15  _kernel_count            5000 non-null   int64
#  16  _title                   5000 non-null   object
#  17  _topic_count             5000 non-null   int64
#  18  _view_count              5000 non-null   int64
#  19  _vote_count              5000 non-null   int64
#  20  _current_version_number  5000 non-null   int64
#  21  _usability_rating        5000 non-null   float64
#  22  _tags                    5000 non-null   object
#  23  _files                   5000 non-null   object
#  24  _versions                5000 non-null   object
#  25  _is_frozen               5000 non-null   bool
# dtypes: bool(3), float64(2), int64(8), object(13)
# memory usage: 913.2+ KB

# %%
columns_list = list(df.columns)
print(columns_list)
# Out:
# ['_id', '_ref', '_subtitle', '_creator_name', '_creator_url', '_total_bytes', '_url', '_last_updated', '_download_count', '_is_private', '_is_featured', '_license_name', '_description', '_owner_name', '_owner_ref', '_kernel_count', '_title', '_topic_count', '_view_count', '_vote_count', '_current_version_number', '_usability_rating', '_tags', '_files', '_versions', '_is_frozen']

# %%
# Barcha ustun nomlaridagi boshidagi '_' belgini olib tashlash
df.columns = [col.lstrip('_') for col in df.columns]

# Natijani tekshirish
print(df.columns)
# Out:
# Index(['id', 'ref', 'subtitle', 'creator_name', 'creator_url', 'total_bytes',
#        'url', 'last_updated', 'download_count', 'is_private', 'is_featured',
#        'license_name', 'description', 'owner_name', 'owner_ref',
#        'kernel_count', 'title', 'topic_count', 'view_count', 'vote_count',
#        'current_version_number', 'usability_rating', 'tags', 'files',
#        'versions', 'is_frozen'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      5000 non-null   int64
#  1   ref                     5000 non-null   object
#  2   subtitle                5000 non-null   object
#  3   creator_name            5000 non-null   object
#  4   creator_url             5000 non-null   object
#  5   total_bytes             5000 non-null   int64
#  6   url                     5000 non-null   object
#  7   last_updated            5000 non-null   object
#  8   download_count          5000 non-null   int64
#  9   is_private              5000 non-null   bool
#  10  is_featured             5000 non-null   bool
#  11  license_name            5000 non-null   object
#  12  description             0 non-null      float64
#  13  owner_name              5000 non-null   object
#  14  owner_ref               5000 non-null   object
#  15  kernel_count            5000 non-null   int64
#  16  title                   5000 non-null   object
#  17  topic_count             5000 non-null   int64
#  18  view_count              5000 non-null   int64
#  19  vote_count              5000 non-null   int64
#  20  current_version_number  5000 non-null   int64
#  21  usability_rating        5000 non-null   float64
#  22  tags                    5000 non-null   object
#  23  files                   5000 non-null   object
#  24  versions                5000 non-null   object
#  25  is_frozen               5000 non-null   bool
# dtypes: bool(3), float64(2), int64(8), object(13)
# memory usage: 913.2+ KB

# %%
# Har bir ustundagi NaN (bosh) qiymatlar soni
nan_counts = df.isna().sum()

print(nan_counts)
# Out:
# id                           0
# ref                          0
# subtitle                     0
# creator_name                 0
# creator_url                  0
# total_bytes                  0
# url                          0
# last_updated                 0
# download_count               0
# is_private                   0
# is_featured                  0
# license_name                 0
# description               5000
# owner_name                   0
# owner_ref                    0
# kernel_count                 0
# title                        0
# topic_count                  0
# view_count                   0
# vote_count                   0
# current_version_number       0
# usability_rating             0
# tags                         0
# files                        0
# versions                     0
# is_frozen                    0
# dtype: int64
