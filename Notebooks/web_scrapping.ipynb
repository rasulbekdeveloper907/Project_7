# %%
import sys
import os
import logging

# Log fayl manzili
log_path = r"C:\Users\Rasulbek907\Desktop\Project_MP\Log\data_loader.log"

# Log fayli mavjud papka borligini tekshirish
os.makedirs(os.path.dirname(log_path), exist_ok=True)

# Log sozlamalari
logging.basicConfig(
    filename=log_path,
    filemode='a',
    format='%(asctime)s - %(levelname)s - %(message)s',
    level=logging.INFO
)

# %%
import os
import json
import time
import pandas as pd
from kaggle.api.kaggle_api_extended import KaggleApi

# -----------------------------
# Kaggle API sozlash funksiyasi
# -----------------------------
def setup_kaggle_api():
    kaggle_dir = os.path.join(os.path.expanduser('~'), '.kaggle')
    kaggle_file = os.path.join(kaggle_dir, 'kaggle.json')

    if not os.path.exists(kaggle_dir):
        os.makedirs(kaggle_dir, exist_ok=True)

    if not os.path.exists(kaggle_file):
        print("⚙️ Kaggle API token topilmadi.")
        username = input("Kaggle username kiriting: ").strip()
        key = input("Kaggle API key (token) kiriting: ").strip()
        data = {"username": username, "key": key}
        with open(kaggle_file, 'w', encoding='utf-8') as f:
            json.dump(data, f)
        print(f"✅ Token saqlandi: {kaggle_file}")

    os.chmod(kaggle_file, 0o600)
    print("🔐 Ruxsatlar to‘g‘rilandi.")

    api = KaggleApi()
    api.authenticate()
    print("✅ Kaggle API muvaffaqiyatli autentifikatsiya qilindi.")

    return api

# -----------------------------
# Unikal datasetlarni olish funksiyasi
# -----------------------------
def fetch_unique_datasets(api, total=8000, delay=0.5):
    all_data = []
    seen_dataset_refs = set()  # Unikal datasetlarni saqlash uchun
    page = 1

    while len(all_data) < total:
        print(f"📦 Sahifa {page} yuklanmoqda... ({len(all_data)}/{total})")
        try:
            datasets = api.dataset_list(sort_by="hottest", page=page)
        except Exception as e:
            print(f"⚠️ API xatosi: {e}")
            break

        if not datasets:
            print("❌ Yangi dataset topilmadi, to‘xtatildi.")
            break

        for d in datasets:
            if d.ref not in seen_dataset_refs:
                seen_dataset_refs.add(d.ref)
                all_data.append(vars(d))
            if len(all_data) >= total:
                break

        page += 1
        time.sleep(delay)

    print(f"✅ Jami {len(all_data)} ta unikal dataset yig‘ildi.")
    return all_data

# -----------------------------
# CSV ga saqlash funksiyasi
# -----------------------------
def save_to_csv(data, filename='kaggle_unique_datasets_8000.csv'):
    output_dir = r"C:\Users\Rasulbek907\Desktop\Project_MP\Data\Web_Scrapping"
    if not os.path.exists(output_dir):
        os.makedirs(output_dir, exist_ok=True)
    
    full_path = os.path.join(output_dir, filename)

    df = pd.json_normalize(data)
    df.to_csv(full_path, index=False, encoding='utf-8-sig')
    print(f"💾 Fayl saqlandi: {full_path} ({len(df)} yozuv)")

# -----------------------------
# Main funksiyasi
# -----------------------------
def main():
    api = setup_kaggle_api()
    data = fetch_unique_datasets(api, total=3000)
    save_to_csv(data)

# -----------------------------
# Ishga tushirish
# -----------------------------
if __name__ == '__main__':
    main()
# Out:
# 🔐 Ruxsatlar to‘g‘rilandi.
# ✅ Kaggle API muvaffaqiyatli autentifikatsiya qilindi.
# 📦 Sahifa 1 yuklanmoqda... (0/3000)
# 📦 Sahifa 2 yuklanmoqda... (20/3000)
# 📦 Sahifa 3 yuklanmoqda... (40/3000)
# 📦 Sahifa 4 yuklanmoqda... (59/3000)
# 📦 Sahifa 5 yuklanmoqda... (79/3000)
# 📦 Sahifa 6 yuklanmoqda... (99/3000)
# 📦 Sahifa 7 yuklanmoqda... (119/3000)
# 📦 Sahifa 8 yuklanmoqda... (139/3000)
# 📦 Sahifa 9 yuklanmoqda... (157/3000)
# 📦 Sahifa 10 yuklanmoqda... (176/3000)
# 📦 Sahifa 11 yuklanmoqda... (196/3000)
# 📦 Sahifa 12 yuklanmoqda... (216/3000)
# 📦 Sahifa 13 yuklanmoqda... (236/3000)
# 📦 Sahifa 14 yuklanmoqda... (256/3000)
# 📦 Sahifa 15 yuklanmoqda... (276/3000)
# 📦 Sahifa 16 yuklanmoqda... (296/3000)
# 📦 Sahifa 17 yuklanmoqda... (316/3000)
# 📦 Sahifa 18 yuklanmoqda... (336/3000)
# 📦 Sahifa 19 yuklanmoqda... (356/3000)
# 📦 Sahifa 20 yuklanmoqda... (376/3000)
# 📦 Sahifa 21 yuklanmoqda... (395/3000)
# 📦 Sahifa 22 yuklanmoqda... (414/3000)
# 📦 Sahifa 23 yuklanmoqda... (434/3000)
# ...

# %%
import os
import json
import time
import pandas as pd
from kaggle.api.kaggle_api_extended import KaggleApi
from tqdm import tqdm  # progress bar uchun

# -----------------------------
# Kaggle API sozlash funksiyasi
# -----------------------------
def setup_kaggle_api():
    kaggle_dir = os.path.join(os.path.expanduser('~'), '.kaggle')
    kaggle_file = os.path.join(kaggle_dir, 'kaggle.json')

    if not os.path.exists(kaggle_dir):
        os.makedirs(kaggle_dir, exist_ok=True)

    if not os.path.exists(kaggle_file):
        print("⚙️ Kaggle API token topilmadi.")
        username = input("Kaggle username kiriting: ").strip()
        key = input("Kaggle API key (token) kiriting: ").strip()
        data = {"username": username, "key": key}
        with open(kaggle_file, 'w', encoding='utf-8') as f:
            json.dump(data, f)
        print(f"✅ Token saqlandi: {kaggle_file}")

    os.chmod(kaggle_file, 0o600)
    print("🔐 Ruxsatlar to‘g‘rilandi.")

    api = KaggleApi()
    api.authenticate()
    print("✅ Kaggle API muvaffaqiyatli autentifikatsiya qilindi.")

    return api

# -----------------------------
# Unikal datasetlarni olish funksiyasi
# -----------------------------
def fetch_unique_datasets(api, total=8000, delay=1.5, max_retries=3):
    all_data = []
    seen_dataset_refs = set()  # Unikal datasetlarni saqlash uchun
    page = 1

    with tqdm(total=total, desc="📦 Datasetlar yig‘ilmoqda") as pbar:
        while len(all_data) < total:
            for attempt in range(max_retries):
                try:
                    datasets = api.dataset_list(sort_by="hottest", page=page)
                    break
                except Exception as e:
                    print(f"⚠️ API xatosi: {e}, retry {attempt+1}/{max_retries}")
                    time.sleep(5)
            else:
                print("❌ API bilan bog‘lanib bo‘lmadi, to‘xtatildi.")
                break

            if not datasets:
                print("❌ Yangi dataset topilmadi, to‘xtatildi.")
                break

            for d in datasets:
                if d.ref not in seen_dataset_refs:
                    seen_dataset_refs.add(d.ref)
                    all_data.append(vars(d))
                    pbar.update(1)
                if len(all_data) >= total:
                    break

            page += 1
            time.sleep(delay)

    print(f"✅ Jami {len(all_data)} ta unikal dataset yig‘ildi.")
    return all_data

# -----------------------------
# CSV ga saqlash funksiyasi
# -----------------------------
def save_to_csv(data, filename='kaggle_unique_datasets_8000.csv'):
    output_dir = r"C:\Users\Rasulbek907\Desktop\Project_MP\Data\Web_Scrapping"
    if not os.path.exists(output_dir):
        os.makedirs(output_dir, exist_ok=True)
    
    full_path = os.path.join(output_dir, filename)

    df = pd.json_normalize(data)
    df.to_csv(full_path, index=False, encoding='utf-8-sig')
    print(f"💾 Fayl saqlandi: {full_path} ({len(df)} yozuv)")

# -----------------------------
# Main funksiyasi
# -----------------------------
def main():
    api = setup_kaggle_api()
    data = fetch_unique_datasets(api, total=8000)  # 8000 dataset uchun
    save_to_csv(data)

# -----------------------------
# Ishga tushirish
# -----------------------------
if __name__ == '__main__':
    main()
# Out:
# 🔐 Ruxsatlar to‘g‘rilandi.
# ✅ Kaggle API muvaffaqiyatli autentifikatsiya qilindi.
# 📦 Datasetlar yig‘ilmoqda: 100%|██████████| 8000/8000 [16:48<00:00,  7.93it/s]
# ✅ Jami 8000 ta unikal dataset yig‘ildi.
# 💾 Fayl saqlandi: C:\Users\Rasulbek907\Desktop\Project_MP\Data\Web_Scrapping\kaggle_unique_datasets_8000.csv (8000 yozuv)
